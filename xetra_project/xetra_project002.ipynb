# %% [markdown]
# # Date as an input Argument

# %%
import boto3
import pandas as pd
from io import StringIO, BytesIO
from datetime import datetime, timedelta

# %%
arg_date = "2021-05-07"

# %%
arg_date_dt = datetime.strptime(arg_date, "%Y-%m-%d").date() - timedelta(days = 1)

# %%
arg_date_dt
# Out:
# datetime.date(2021, 5, 6)

# %%
arg_date_end = datetime.strptime(arg_date, "%Y-%m-%d").date() + timedelta(days = 2)

# %%
arg_date_end
# Out:
# datetime.date(2021, 5, 9)

# %%
s3 = boto3.resource("s3")
bucket = s3.Bucket("deutsche-boerse-xetra-pds")

# %%
# objects = [obj for obj in bucket.objects.all() if datetime.strptime(obj.key.split("/")[0], '%Y-%m-%d').date() >= arg_date_dt]
objects = [obj for obj in bucket.objects.all() if datetime.strptime(obj.key.split("/")[0], '%Y-%m-%d').date() >= arg_date_dt 
           if datetime.strptime(obj.key.split("/")[0], '%Y-%m-%d').date() <= arg_date_end]

# %%
#objects = []
#for obj in bucket.objects.all():
   # d = datetime.strptime(obj.key.split("/")[0], '%Y-%m-%d').date()
   # if d >= arg_date_dt and d <= arg_date_end:
     #   objects.append(obj)

# %%
objects
# Out:
# [s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-06/2021-05-06_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-05-07/2021-05-07_BINS_XETR23.csv')]

# %%
csv_obj_init = bucket.Object(key= objects[0].key).get().get("Body").read().decode("utf-8")
data = StringIO(csv_obj_init)
df_init = pd.read_csv(data, delimiter = ",")

# %%
df_init.columns
# Out:
# Index(['ISIN', 'Mnemonic', 'SecurityDesc', 'SecurityType', 'Currency',
#        'SecurityID', 'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice',
#        'EndPrice', 'TradedVolume', 'NumberOfTrades'],
#       dtype='object')

# %%
df_all = pd.DataFrame(columns = df_init.columns)
for obj in objects:
    csv_obj = bucket.Object(key = obj.key).get().get("Body").read().decode("utf-8")
    data = StringIO(csv_obj)
    df = pd.read_csv(data, delimiter = ",")
    df_all = df_all.append(df, ignore_index = True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7976\1031197490.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_all.append(df, ignore_index = True)

# %%
df_all
# Out:
#                 ISIN Mnemonic              SecurityDesc  SecurityType  \
# 0       AT0000A0E9W5     SANT               S+T AG O.N.  Common stock
# 1       DE000A0DJ6J9      S92      SMA SOLAR TECHNOL.AG  Common stock
# 2       DE000A0D6554     NDX1            NORDEX SE O.N.  Common stock
# 3       DE000A0D9PT0      MTX  MTU AERO ENGINES NA O.N.  Common stock
# 4       DE000A0HN5C6     DWNI    DEUTSCHE WOHNEN SE INH  Common stock
# ...              ...      ...                       ...           ...
# 212153  DE0006062144     1COV         COVESTRO AG  O.N.  Common stock
# 212154  DE000A2TSQH7     KTEK        KATEK SE  INH O.N.  Common stock
# 212155  DE0007236101      SIE       SIEMENS AG  NA O.N.  Common stock
# 212156  DE000A0TGJ55     VAR1             VARTA AG O.N.  Common stock
# 212157  DE000A0JK2A8      AR4   AURELIUS EQ.OPP.   O.N.  Common stock
#
#        Currency SecurityID        Date   Time StartPrice MaxPrice MinPrice  \
# 0           EUR    2504159  2021-05-06  07:00      21.52     21.9    21.52
# 1           EUR    2504287  2021-05-06  07:00      46.02    46.02    45.82
# 2           EUR    2504290  2021-05-06  07:00      21.56    21.78    21.56
# 3           EUR    2504297  2021-05-06  07:00      203.6    203.6    202.5
# 4           EUR    2504314  2021-05-06  07:00      44.18    44.21    44.04
# ...         ...        ...         ...    ...        ...      ...      ...
# 212153      EUR    2505008  2021-05-07  15:43      58.02    58.02    58.02
# 212154      EUR    6366023  2021-05-07  15:43       26.5     26.5     26.5
# 212155      EUR    2505088  2021-05-07  15:44     144.28   144.28   144.28
# 212156      EUR    2721826  2021-05-07  15:44     115.75   115.75   115.75
# 212157      EUR    2504340  2021-05-07  15:45      27.72    27.72    27.72
#
#        EndPrice TradedVolume NumberOfTrades
# 0         21.82         2648             10
# 1         45.84         1766             10
# 2         21.78        14935             14
# 3         202.5         1246              9
# 4         44.08        12002             31
# ...         ...          ...            ...
# 212153    58.02           51              1
# 212154     26.5          437              1
# 212155   144.28         3969              1
# 212156   115.75          795              1
# 212157    27.72          191              1
#
# [212158 rows x 14 columns]

# %%
columns = ['ISIN', 'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice', 'EndPrice', 'TradedVolume']
df_all = df_all.loc[:, columns]

# %%
df_all
# Out:
#                 ISIN        Date   Time StartPrice MaxPrice MinPrice EndPrice  \
# 0       AT0000A0E9W5  2021-05-06  07:00      21.52     21.9    21.52    21.82
# 1       DE000A0DJ6J9  2021-05-06  07:00      46.02    46.02    45.82    45.84
# 2       DE000A0D6554  2021-05-06  07:00      21.56    21.78    21.56    21.78
# 3       DE000A0D9PT0  2021-05-06  07:00      203.6    203.6    202.5    202.5
# 4       DE000A0HN5C6  2021-05-06  07:00      44.18    44.21    44.04    44.08
# ...              ...         ...    ...        ...      ...      ...      ...
# 212153  DE0006062144  2021-05-07  15:43      58.02    58.02    58.02    58.02
# 212154  DE000A2TSQH7  2021-05-07  15:43       26.5     26.5     26.5     26.5
# 212155  DE0007236101  2021-05-07  15:44     144.28   144.28   144.28   144.28
# 212156  DE000A0TGJ55  2021-05-07  15:44     115.75   115.75   115.75   115.75
# 212157  DE000A0JK2A8  2021-05-07  15:45      27.72    27.72    27.72    27.72
#
#        TradedVolume
# 0              2648
# 1              1766
# 2             14935
# 3              1246
# 4             12002
# ...             ...
# 212153           51
# 212154          437
# 212155         3969
# 212156          795
# 212157          191
#
# [212158 rows x 8 columns]

# %%
df_all.dropna(inplace = True)

# %%
df_all.shape
# Out:
# (212158, 8)

# %% [markdown]
# ## Get opening price per ISIN and Day

# %%
df_all["opening_price"] = df_all.sort_values(by=["Time"]).groupby(["ISIN", "Date"])["StartPrice"].transform("first")

# %%
df_all[df_all["ISIN"] == "AT0000A0E9W5"]
# Out:
#                 ISIN        Date   Time StartPrice MaxPrice MinPrice EndPrice  \
# 0       AT0000A0E9W5  2021-05-06  07:00      21.52     21.9    21.52    21.82
# 151     AT0000A0E9W5  2021-05-06  07:01       21.9     21.9    21.78    21.78
# 273     AT0000A0E9W5  2021-05-06  07:02      21.76    22.04    21.76    22.04
# 673     AT0000A0E9W5  2021-05-06  07:04       22.0    22.04     22.0     22.0
# 2845    AT0000A0E9W5  2021-05-06  07:05       22.0    22.06     22.0    22.04
# ...              ...         ...    ...        ...      ...      ...      ...
# 207474  AT0000A0E9W5  2021-05-07  15:25      21.16    21.18    21.16    21.18
# 207740  AT0000A0E9W5  2021-05-07  15:26      21.16    21.16    21.16    21.16
# 207990  AT0000A0E9W5  2021-05-07  15:27      21.14     21.2    21.14    21.18
# 208591  AT0000A0E9W5  2021-05-07  15:29      21.18    21.22    21.16    21.22
# 209135  AT0000A0E9W5  2021-05-07  15:35      21.22    21.22    21.22    21.22
#
#        TradedVolume opening_price
# 0              2648         21.52
# 151             373         21.52
# 273            9534         21.52
# 673            8376         21.52
# 2845           2002         21.52
# ...             ...           ...
# 207474          539          21.7
# 207740            2          21.7
# 207990         1998          21.7
# 208591         1259          21.7
# 209135        35449          21.7
#
# [509 rows x 9 columns]

# %% [markdown]
# ## Get closing price per ISIN and Day

# %%
df_all["closing_price"] = df_all.sort_values(by=["Time"]).groupby(["ISIN", "Date"])["StartPrice"].transform("last")

# %%
df_all[df_all["ISIN"] == "AT0000A0E9W5"]
# Out:
#                 ISIN        Date   Time StartPrice MaxPrice MinPrice EndPrice  \
# 0       AT0000A0E9W5  2021-05-06  07:00      21.52     21.9    21.52    21.82
# 151     AT0000A0E9W5  2021-05-06  07:01       21.9     21.9    21.78    21.78
# 273     AT0000A0E9W5  2021-05-06  07:02      21.76    22.04    21.76    22.04
# 673     AT0000A0E9W5  2021-05-06  07:04       22.0    22.04     22.0     22.0
# 2845    AT0000A0E9W5  2021-05-06  07:05       22.0    22.06     22.0    22.04
# ...              ...         ...    ...        ...      ...      ...      ...
# 207474  AT0000A0E9W5  2021-05-07  15:25      21.16    21.18    21.16    21.18
# 207740  AT0000A0E9W5  2021-05-07  15:26      21.16    21.16    21.16    21.16
# 207990  AT0000A0E9W5  2021-05-07  15:27      21.14     21.2    21.14    21.18
# 208591  AT0000A0E9W5  2021-05-07  15:29      21.18    21.22    21.16    21.22
# 209135  AT0000A0E9W5  2021-05-07  15:35      21.22    21.22    21.22    21.22
#
#        TradedVolume opening_price closing_price
# 0              2648         21.52          21.5
# 151             373         21.52          21.5
# 273            9534         21.52          21.5
# 673            8376         21.52          21.5
# 2845           2002         21.52          21.5
# ...             ...           ...           ...
# 207474          539          21.7         21.22
# 207740            2          21.7         21.22
# 207990         1998          21.7         21.22
# 208591         1259          21.7         21.22
# 209135        35449          21.7         21.22
#
# [509 rows x 10 columns]

# %% [markdown]
# ## Aggregation

# %%
df_all = df_all.groupby(["ISIN", "Date"], as_index = False).agg(opening_price_eur = ("opening_price", "min"),
                                                                closing_price_eur = ("closing_price", "min"), 
                                                                minimum_price_eur = ("MinPrice", "min"),
                                                                maximum_price_eur = ("MaxPrice", "max"),
                                                                daily_traded_volume = ("TradedVolume", "sum"))

# %%
df_all
# Out:
#               ISIN        Date  opening_price_eur  closing_price_eur  \
# 0     AT00000FACC2  2021-05-06              8.880              8.730
# 1     AT00000FACC2  2021-05-07              8.860              9.000
# 2     AT0000606306  2021-05-06             18.500             18.300
# 3     AT0000606306  2021-05-07             18.650             18.740
# 4     AT0000609607  2021-05-06             16.340             16.340
# ...            ...         ...                ...                ...
# 5965  XS2265369731  2021-05-07             10.378             10.344
# 5966  XS2265370234  2021-05-06             24.892             24.446
# 5967  XS2265370234  2021-05-07             24.606             24.108
# 5968  XS2284324667  2021-05-06             26.744             26.686
# 5969  XS2284324667  2021-05-07             26.680             26.658
#
#       minimum_price_eur  maximum_price_eur daily_traded_volume
# 0                 8.730              8.880                 943
# 1                 8.840              9.000                 547
# 2                18.300             18.540                9273
# 3                18.600             18.740                1283
# 4                16.340             16.340                   0
# ...                 ...                ...                 ...
# 5965             10.344             10.439                   0
# 5966             24.222             24.892                1250
# 5967             23.766             24.606                1848
# 5968             26.586             26.744                2721
# 5969             26.430             26.680                5211
#
# [5970 rows x 7 columns]

# %% [markdown]
# ## Percent Change Prev Closing

# %%
df_all["prev_closing_price"] = df_all.sort_values(by = ["Date"]).groupby(["ISIN"])["closing_price_eur"].shift(1)

# %%
df_all
# Out:
#               ISIN        Date  opening_price_eur  closing_price_eur  \
# 0     AT00000FACC2  2021-05-06              8.880              8.730
# 1     AT00000FACC2  2021-05-07              8.860              9.000
# 2     AT0000606306  2021-05-06             18.500             18.300
# 3     AT0000606306  2021-05-07             18.650             18.740
# 4     AT0000609607  2021-05-06             16.340             16.340
# ...            ...         ...                ...                ...
# 5965  XS2265369731  2021-05-07             10.378             10.344
# 5966  XS2265370234  2021-05-06             24.892             24.446
# 5967  XS2265370234  2021-05-07             24.606             24.108
# 5968  XS2284324667  2021-05-06             26.744             26.686
# 5969  XS2284324667  2021-05-07             26.680             26.658
#
#       minimum_price_eur  maximum_price_eur daily_traded_volume  \
# 0                 8.730              8.880                 943
# 1                 8.840              9.000                 547
# 2                18.300             18.540                9273
# 3                18.600             18.740                1283
# 4                16.340             16.340                   0
# ...                 ...                ...                 ...
# 5965             10.344             10.439                   0
# 5966             24.222             24.892                1250
# 5967             23.766             24.606                1848
# 5968             26.586             26.744                2721
# 5969             26.430             26.680                5211
#
#       prev_closing_price
# 0                    NaN
# 1                  8.730
# 2                    NaN
# 3                 18.300
# 4                    NaN
# ...                  ...
# 5965              10.412
# 5966                 NaN
# 5967              24.446
# 5968                 NaN
# 5969              26.686
#
# [5970 rows x 8 columns]

# %%
df_all["change_prev_closing_%"] = (df_all["closing_price_eur"] - df_all["prev_closing_price"]) / df_all["prev_closing_price"] * 100

# %%
df_all.drop(columns = ["prev_closing_price"], inplace = True)

# %%
df_all = df_all.round(2)

# %%
df_all = df_all[df_all.Date >= arg_date]

# %%
df_all
# Out:
#               ISIN        Date  opening_price_eur  closing_price_eur  \
# 1     AT00000FACC2  2021-05-07               8.86               9.00
# 3     AT0000606306  2021-05-07              18.65              18.74
# 5     AT0000609607  2021-05-07              16.42              16.62
# 7     AT0000644505  2021-05-07             114.40             111.60
# 9     AT0000652011  2021-05-07              30.93              31.23
# ...            ...         ...                ...                ...
# 5961  XS2265368097  2021-05-07              15.10              15.10
# 5963  XS2265369574  2021-05-07              22.68              22.57
# 5965  XS2265369731  2021-05-07              10.38              10.34
# 5967  XS2265370234  2021-05-07              24.61              24.11
# 5969  XS2284324667  2021-05-07              26.68              26.66
#
#       minimum_price_eur  maximum_price_eur daily_traded_volume  \
# 1                  8.84               9.00                 547
# 3                 18.60              18.74                1283
# 5                 16.42              16.70                  95
# 7                111.00             114.40                 928
# 9                 30.70              31.23                4463
# ...                 ...                ...                 ...
# 5961              15.08              15.10                   0
# 5963              22.57              22.68                  22
# 5965              10.34              10.44                   0
# 5967              23.77              24.61                1848
# 5969              26.43              26.68                5211
#
#       change_prev_closing_%
# 1                      3.09
# 3                      2.40
# 5                      1.71
# 7                     -2.45
# 9                      0.35
# ...                     ...
# 5961                  -0.44
# 5963                  -1.03
# 5965                  -0.65
# 5967                  -1.38
# 5969                  -0.10
#
# [2991 rows x 8 columns]

# %% [markdown]
# ## Write to S3

# %%
key = "xetra_daily_report" + datetime.today().strftime("%Y%m%d_%H%M%S") + ".parquet"

# %%
out_buffer = BytesIO()
df_all.to_parquet(out_buffer, index = False)
bucket_target = s3.Bucket("xetra--1234")
bucket_target.put_object(Body = out_buffer.getvalue(), Key = key)
# Out:
# s3.Object(bucket_name='xetra--1234', key='xetra_daily_report20220209_205648.parquet')

# %% [markdown]
# ## Read the uploaded file

# %%
for obj in bucket_target.objects.all():
    print(obj.key)
# Out:
# xetra_daily_report20220209_205648.parquet

# %%
prq_obj = bucket_target.Object(key = "xetra_daily_report20220209_205648.parquet").get().get("Body").read()
data = BytesIO(prq_obj)
df_report = pd.read_parquet(data)

# %%
df_report
# Out:
#               ISIN        Date  opening_price_eur  closing_price_eur  \
# 0     AT00000FACC2  2021-05-07               8.86               9.00
# 1     AT0000606306  2021-05-07              18.65              18.74
# 2     AT0000609607  2021-05-07              16.42              16.62
# 3     AT0000644505  2021-05-07             114.40             111.60
# 4     AT0000652011  2021-05-07              30.93              31.23
# ...            ...         ...                ...                ...
# 2986  XS2265368097  2021-05-07              15.10              15.10
# 2987  XS2265369574  2021-05-07              22.68              22.57
# 2988  XS2265369731  2021-05-07              10.38              10.34
# 2989  XS2265370234  2021-05-07              24.61              24.11
# 2990  XS2284324667  2021-05-07              26.68              26.66
#
#       minimum_price_eur  maximum_price_eur  daily_traded_volume  \
# 0                  8.84               9.00                  547
# 1                 18.60              18.74                 1283
# 2                 16.42              16.70                   95
# 3                111.00             114.40                  928
# 4                 30.70              31.23                 4463
# ...                 ...                ...                  ...
# 2986              15.08              15.10                    0
# 2987              22.57              22.68                   22
# 2988              10.34              10.44                    0
# 2989              23.77              24.61                 1848
# 2990              26.43              26.68                 5211
#
#       change_prev_closing_%
# 0                      3.09
# 1                      2.40
# 2                      1.71
# 3                     -2.45
# 4                      0.35
# ...                     ...
# 2986                  -0.44
# 2987                  -1.03
# 2988                  -0.65
# 2989                  -1.38
# 2990                  -0.10
#
# [2991 rows x 8 columns]
