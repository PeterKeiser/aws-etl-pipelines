# %%
import boto3
import pandas as pd
from io import StringIO
import os, glob
from datetime import datetime, timedelta

# %%
arg_date = '2021-03-30'

# %%
arg_date_dt = datetime.strptime(arg_date, '%Y-%m-%d').date() - timedelta(days=1)

# %%
arg_date_dt
# Out:
# datetime.date(2021, 3, 29)

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('deutsche-boerse-xetra-pds')

# %%
objects = [obj for obj in bucket.objects.all() if datetime.strptime(obj.key.split("/")[0], '%Y-%m-%d').date() == arg_date_dt]

# %%
objects
# Out:
# [s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='deutsche-boerse-xetra-pds', key='2021-03-29/2021-03-29_BINS_XETR23.csv')]

# %%
 datetime.strptime(obj.key.split("/")[0]

# %%
objects = [obj for obj in bucket.objects.all() if datetime.strptime(obj.key.split("/")[0], '%Y-%m-%d').date() >= arg_date_dt]
# Out:
# KeyboardInterrupt

# %%
objects

# %%
csv_obj_init = bucket.Object(key=objects[0].key).get().get('Body').read().decode('utf-8')
data = StringIO(csv_obj_init)
df_init = pd.read_csv(data, delimiter=',')

# %%
df_init.columns
# Out:
# Index(['ISIN', 'Mnemonic', 'SecurityDesc', 'SecurityType', 'Currency',
#        'SecurityID', 'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice',
#        'EndPrice', 'TradedVolume', 'NumberOfTrades'],
#       dtype='object')

# %% [markdown]
# Less efficient method (not pythonic) -> more efficient pd.concat([pd.DataFrame([i], columns=['A']) for i in range(5)],
#           ignore_index=True)

# %%
df_all = pd.DataFrame(columns=df_init.columns)
for obj in objects:
    csv_obj = bucket.Object(key=obj.key).get().get('Body').read().decode('utf-8')
    data = StringIO(csv_obj)
    df = pd.read_csv(data, delimiter=',')
    df_all = df_all.append(df, ignore_index=True)

# %%
df_all.head(10)
# Out:
#            ISIN Mnemonic               SecurityDesc  SecurityType Currency  \
# 0  AT0000A0E9W5     SANT                S+T AG O.N.  Common stock      EUR
# 1  DE000A0DJ6J9      S92       SMA SOLAR TECHNOL.AG  Common stock      EUR
# 2  DE000A0D6554     NDX1             NORDEX SE O.N.  Common stock      EUR
# 3  DE000A0D9PT0      MTX   MTU AERO ENGINES NA O.N.  Common stock      EUR
# 4  DE000A0HN5C6     DWNI     DEUTSCHE WOHNEN SE INH  Common stock      EUR
# 5  DE000A0JL9W6      VBK  VERBIO VER.BIOENERGIE  ON  Common stock      EUR
# 6  DE000A0LD2U1      AOX     ALSTRIA OFFICE REIT-AG  Common stock      EUR
# 7  DE000A0LD6E6      GXI            GERRESHEIMER AG  Common stock      EUR
# 8  DE000A0S8488     HHFA  HAMBURG.HAFEN LOG.A-SP NA  Common stock      EUR
# 9  DE000A0WMPJ6     AIXA         AIXTRON SE NA O.N.  Common stock      EUR
#
#   SecurityID        Date   Time  StartPrice  MaxPrice  MinPrice  EndPrice  \
# 0    2504159  2021-03-29  07:00      21.180    21.200     21.18     21.20
# 1    2504287  2021-03-29  07:00      48.420    48.420     48.42     48.42
# 2    2504290  2021-03-29  07:00      25.780    25.900     25.78     25.90
# 3    2504297  2021-03-29  07:00     198.000   198.000    198.00    198.00
# 4    2504314  2021-03-29  07:00      40.410    40.450     40.40     40.45
# 5    2504343  2021-03-29  07:00      35.800    35.800     35.80     35.80
# 6    2504379  2021-03-29  07:00      14.040    14.040     14.04     14.04
# 7    2504380  2021-03-29  07:00      83.650    83.650     83.35     83.50
# 8    2504409  2021-03-29  07:00      19.640    19.640     19.64     19.64
# 9    2504428  2021-03-29  07:00      18.885    18.885     18.86     18.88
#
#   TradedVolume NumberOfTrades
# 0          611              3
# 1         1001              1
# 2        10936              9
# 3          239              1
# 4         6672             11
# 5         2965              2
# 6          626              1
# 7         3251             24
# 8         1354              1
# 9        10523             34

# %%
columns = ["ISIN", "Mnemonic", "Date", "Time", "StartPrice", "EndPrice", "MinPrice", "MaxPrice", "TradedVolume"]
df_all = df_all.loc[:, columns]

# %%
df_all
# Out:
#                 ISIN Mnemonic        Date   Time  StartPrice  EndPrice  \
# 0       AT0000A0E9W5     SANT  2021-03-29  07:00      21.180    21.200
# 1       DE000A0DJ6J9      S92  2021-03-29  07:00      48.420    48.420
# 2       DE000A0D6554     NDX1  2021-03-29  07:00      25.780    25.900
# 3       DE000A0D9PT0      MTX  2021-03-29  07:00     198.000   198.000
# 4       DE000A0HN5C6     DWNI  2021-03-29  07:00      40.410    40.450
# ...              ...      ...         ...    ...         ...       ...
# 383434  DK0010268606      VWS  2021-04-01  15:40     176.340   176.340
# 383435  DE000TUAG000     TUI1  2021-04-01  15:42       4.483     4.483
# 383436  DE0006599905      MRK  2021-04-01  15:42     145.550   145.550
# 383437  DK0010268606      VWS  2021-04-01  15:43     176.340   176.340
# 383438  DE000A1ML7J1      VNA  2021-04-01  15:44      56.660    56.660
#
#         MinPrice  MaxPrice TradedVolume
# 0         21.180    21.200          611
# 1         48.420    48.420         1001
# 2         25.780    25.900        10936
# 3        198.000   198.000          239
# 4         40.400    40.450         6672
# ...          ...       ...          ...
# 383434   176.340   176.340           50
# 383435     4.483     4.483         2039
# 383436   145.550   145.550          101
# 383437   176.340   176.340           50
# 383438    56.660    56.660           12
#
# [383439 rows x 9 columns]

# %%
df_all.dropna(inplace=True)

# %%
df_all.shape
# Out:
# (383439, 9)

# %% [markdown]
# ## Get opening price per ISIN and day

# %%
df_all['opening_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN', 'Date'])['StartPrice'].transform('first')

# %%
df_all[df_all['ISIN']=='DE0007568578']
# Out:
#                 ISIN Mnemonic        Date   Time  StartPrice  EndPrice  \
# 957     DE0007568578      F3C  2021-03-29  07:04       24.60     24.65
# 2899    DE0007568578      F3C  2021-03-29  07:05       24.75     24.80
# 3173    DE0007568578      F3C  2021-03-29  07:06       24.80     24.80
# 3459    DE0007568578      F3C  2021-03-29  07:07       24.70     24.85
# 4155    DE0007568578      F3C  2021-03-29  07:10       24.80     24.90
# ...              ...      ...         ...    ...         ...       ...
# 379346  DE0007568578      F3C  2021-04-01  15:27       26.90     26.90
# 379670  DE0007568578      F3C  2021-04-01  15:28       26.75     26.75
# 380034  DE0007568578      F3C  2021-04-01  15:29       26.75     26.70
# 380340  DE0007568578      F3C  2021-04-01  15:30       26.60     26.60
# 381668  DE0007568578      F3C  2021-04-01  15:36       26.75     26.75
#
#         MinPrice  MaxPrice TradedVolume  opening_price
# 957        24.60     24.65         4399          24.60
# 2899       24.75     24.85         1412          24.60
# 3173       24.80     24.80          161          24.60
# 3459       24.60     24.85         1581          24.60
# 4155       24.80     24.90          250          24.60
# ...          ...       ...          ...            ...
# 379346     26.90     26.90           57          27.25
# 379670     26.75     26.75          250          27.25
# 380034     26.70     26.85          278          27.25
# 380340     26.60     26.60          145          27.25
# 381668     26.75     26.75         5321          27.25
#
# [623 rows x 10 columns]

# %% [markdown]
# ## Get closing price per ISIN and day

# %%
df_all['closing_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN', 'Date'])['StartPrice'].transform('last')

# %%
df_all[df_all['ISIN']=='DE0007568578']
# Out:
#                 ISIN Mnemonic        Date   Time  StartPrice  EndPrice  \
# 957     DE0007568578      F3C  2021-03-29  07:04       24.60     24.65
# 2899    DE0007568578      F3C  2021-03-29  07:05       24.75     24.80
# 3173    DE0007568578      F3C  2021-03-29  07:06       24.80     24.80
# 3459    DE0007568578      F3C  2021-03-29  07:07       24.70     24.85
# 4155    DE0007568578      F3C  2021-03-29  07:10       24.80     24.90
# ...              ...      ...         ...    ...         ...       ...
# 379346  DE0007568578      F3C  2021-04-01  15:27       26.90     26.90
# 379670  DE0007568578      F3C  2021-04-01  15:28       26.75     26.75
# 380034  DE0007568578      F3C  2021-04-01  15:29       26.75     26.70
# 380340  DE0007568578      F3C  2021-04-01  15:30       26.60     26.60
# 381668  DE0007568578      F3C  2021-04-01  15:36       26.75     26.75
#
#         MinPrice  MaxPrice TradedVolume  opening_price  closing_price
# 957        24.60     24.65         4399          24.60          24.50
# 2899       24.75     24.85         1412          24.60          24.50
# 3173       24.80     24.80          161          24.60          24.50
# 3459       24.60     24.85         1581          24.60          24.50
# 4155       24.80     24.90          250          24.60          24.50
# ...          ...       ...          ...            ...            ...
# 379346     26.90     26.90           57          27.25          26.75
# 379670     26.75     26.75          250          27.25          26.75
# 380034     26.70     26.85          278          27.25          26.75
# 380340     26.60     26.60          145          27.25          26.75
# 381668     26.75     26.75         5321          27.25          26.75
#
# [623 rows x 11 columns]

# %% [markdown]
# ## Aggregations

# %%
df_all = df_all.groupby(['ISIN', 'Date'], as_index=False).agg(opening_price_eur=('opening_price', 'min'), closing_price_eur=('closing_price', 'min'), minimum_price_eur=('MinPrice', 'min'), maximum_price_eur=('MaxPrice', 'max'), daily_traded_volume=('TradedVolume', 'sum'))

# %%
df_all
# Out:
#                          opening_price_eur  closing_price_eur  \
# ISIN         Date
# AT00000FACC2 2021-03-29              9.040              8.990
#              2021-03-30              9.040              9.120
#              2021-03-31              9.100              9.100
#              2021-04-01              9.180              9.370
# AT0000606306 2021-03-29             18.500             18.400
# ...                                    ...                ...
# XS2265370234 2021-04-01             22.378             22.368
# XS2284324667 2021-03-29             24.726             24.932
#              2021-03-30             25.054             24.916
#              2021-03-31             25.034             24.970
#              2021-04-01             24.804             24.676
#
#                          minimum_price_eur  maximum_price_eur  \
# ISIN         Date
# AT00000FACC2 2021-03-29              8.980              9.040
#              2021-03-30              9.000              9.120
#              2021-03-31              9.100              9.100
#              2021-04-01              9.180              9.430
# AT0000606306 2021-03-29             18.290             18.540
# ...                                    ...                ...
# XS2265370234 2021-04-01             22.368             22.378
# XS2284324667 2021-03-29             24.726             25.180
#              2021-03-30             24.864             25.054
#              2021-03-31             24.770             25.056
#              2021-04-01             24.494             24.848
#
#                          daily_traded_volume
# ISIN         Date
# AT00000FACC2 2021-03-29                  497
#              2021-03-30                  873
#              2021-03-31                    0
#              2021-04-01                  651
# AT0000606306 2021-03-29                 3200
# ...                                      ...
# XS2265370234 2021-04-01                    0
# XS2284324667 2021-03-29                 7596
#              2021-03-30                 2598
#              2021-03-31                 4537
#              2021-04-01                 4594
#
# [11985 rows x 5 columns]

# %% [markdown]
# percent change prev closing

# %%
df_all['prev_closing_price'] = df_all.sort_values(by=['Date']).groupby(['ISIN'])['closing_price_eur'].shift(1)

# %%
df_all
# Out:
#                          opening_price_eur  closing_price_eur  \
# ISIN         Date
# AT00000FACC2 2021-03-29              9.040              8.990
#              2021-03-30              9.040              9.120
#              2021-03-31              9.100              9.100
#              2021-04-01              9.180              9.370
# AT0000606306 2021-03-29             18.500             18.400
# ...                                    ...                ...
# XS2265370234 2021-04-01             22.378             22.368
# XS2284324667 2021-03-29             24.726             24.932
#              2021-03-30             25.054             24.916
#              2021-03-31             25.034             24.970
#              2021-04-01             24.804             24.676
#
#                          minimum_price_eur  maximum_price_eur  \
# ISIN         Date
# AT00000FACC2 2021-03-29              8.980              9.040
#              2021-03-30              9.000              9.120
#              2021-03-31              9.100              9.100
#              2021-04-01              9.180              9.430
# AT0000606306 2021-03-29             18.290             18.540
# ...                                    ...                ...
# XS2265370234 2021-04-01             22.368             22.378
# XS2284324667 2021-03-29             24.726             25.180
#              2021-03-30             24.864             25.054
#              2021-03-31             24.770             25.056
#              2021-04-01             24.494             24.848
#
#                          daily_traded_volume  prev_closing_price
# ISIN         Date
# AT00000FACC2 2021-03-29                  497                 NaN
#              2021-03-30                  873               8.990
#              2021-03-31                    0               9.120
#              2021-04-01                  651               9.100
# AT0000606306 2021-03-29                 3200                 NaN
# ...                                      ...                 ...
# XS2265370234 2021-04-01                    0              22.474
# XS2284324667 2021-03-29                 7596                 NaN
#              2021-03-30                 2598              24.932
#              2021-03-31                 4537              24.916
#              2021-04-01                 4594              24.970
#
# [11985 rows x 6 columns]

# %%
df_all['change_prev_closing_%'] = (df_all['closing_price_eur'] - df_all['prev_closing_price']) / df_all['prev_closing_price'] * 100

# %%
df_all.drop(columns=['prev_closing_price'], inplace=True)

# %%
df_all = df_all.round(decimals=2)

# %%
df_all.reset_index(inplace=True)

# %%
df_all = df_all[df_all.Date >= arg_date]

# %%
df_all
# Out:
#                ISIN        Date  opening_price_eur  closing_price_eur  \
# 1      AT00000FACC2  2021-03-30               9.04               9.12
# 2      AT00000FACC2  2021-03-31               9.10               9.10
# 3      AT00000FACC2  2021-04-01               9.18               9.37
# 5      AT0000606306  2021-03-30              18.74              18.81
# 6      AT0000606306  2021-03-31              18.90              18.73
# ...             ...         ...                ...                ...
# 11979  XS2265370234  2021-03-31              22.47              22.47
# 11980  XS2265370234  2021-04-01              22.38              22.37
# 11982  XS2284324667  2021-03-30              25.05              24.92
# 11983  XS2284324667  2021-03-31              25.03              24.97
# 11984  XS2284324667  2021-04-01              24.80              24.68
#
#        minimum_price_eur  maximum_price_eur  daily_traded_volume  \
# 1                   9.00               9.12                  873
# 2                   9.10               9.10                    0
# 3                   9.18               9.43                  651
# 5                  18.74              18.92                 2900
# 6                  18.73              18.98                 3240
# ...                  ...                ...                  ...
# 11979              22.47              22.47                   67
# 11980              22.37              22.38                    0
# 11982              24.86              25.05                 2598
# 11983              24.77              25.06                 4537
# 11984              24.49              24.85                 4594
#
#        change_prev_closing_%
# 1                       1.45
# 2                      -0.22
# 3                       2.97
# 5                       2.23
# 6                      -0.43
# ...                      ...
# 11979                    NaN
# 11980                  -0.47
# 11982                  -0.06
# 11983                   0.22
# 11984                  -1.18
#
# [9011 rows x 8 columns]
